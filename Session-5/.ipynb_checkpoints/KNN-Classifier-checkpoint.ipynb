# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import math

# %%
df = pd.read_csv("iris.csv")
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
x_train=df.values[:,:4]
y_train=df.values[:,[4]]

# %%
plt.scatter(x_train[:50,0], x_train[:50,2], marker="*",color="red", s=20, linewidths=5)
plt.scatter(x_train[50:100,0], x_train[50:100,2], marker="*",color="blue", s=20, linewidths=5)
plt.scatter(x_train[100:150,0], x_train[100:150,2], marker="*",color="green", s=20, linewidths=5)
plt.title('plot of petal_lentgh vs sepal_length')
plt.xlabel('sepal_length')
plt.ylabel('petal_length')
plt.show()

# %%
plt.scatter(x_train[:50,1], x_train[:50,3], marker="*",color="red", s=20, linewidths=5)
plt.scatter(x_train[50:100,1], x_train[50:100,3], marker="*",color="blue", s=20, linewidths=5)
plt.scatter(x_train[100:150,1], x_train[100:150,3], marker="*",color="green", s=20, linewidths=5)
plt.title('plot of petal_width vs sepal_width')
plt.xlabel('sepal_width')
plt.ylabel('petal_width')
plt.show()

# %%
plt.scatter(x_train[:50,2], x_train[:50,3], marker="*",color="red", s=20, linewidths=5)
plt.scatter(x_train[50:100,2], x_train[50:100,3], marker="*",color="blue", s=20, linewidths=5)
plt.scatter(x_train[100:150,2], x_train[100:150,3], marker="*",color="green", s=20, linewidths=5)
plt.title('plot of petal_lentgh vs sepal_length')
plt.xlabel('sepal_length')
plt.ylabel('petal_length')
plt.show()

# %%
def euclidean_distance(row1, row2):
    distance = 0.0
    for i in range(len(row1)-1):
        distance += (row1[i] - row2[i])**2
    return math.sqrt(distance)

# Locate the most similar neighbors
def get_neighbors(train, test_row, num_neighbors):
    distances = list()
    for train_row in train:
        dist = euclidean_distance(test_row, train_row)
        distances.append((train_row, dist))
    distances.sort(key=lambda tup: tup[1])
    neighbors = list()
    for i in range(num_neighbors):
        neighbors.append(distances[i][0])
    return neighbors
 
# Make a classification prediction with neighbors
def predict_classification(train, test_row, num_neighbors):
    neighbors = get_neighbors(train, test_row, num_neighbors)
    output_values = [row[-1] for row in neighbors]
    prediction = max(set(output_values), key=output_values.count)
    return prediction

# %%
#preparing training and testing data
train_data=np.concatenate((df.values[:40,:],df.values[50:90,:],df.values[100:140,:]),axis=0)
test_data=np.concatenate((df.values[40:50,:],df.values[90:100,:],df.values[140:150,:]),axis=0)

# %%
k=10
correct=0
total=1
for i in test_data:
    correct+=int(predict_classification(train_data, i, k)==i[4])
    total+=1
print(correct*100/total)
# Out:
# 96.7741935483871
